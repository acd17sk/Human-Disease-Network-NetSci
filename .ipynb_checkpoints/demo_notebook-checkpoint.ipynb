# %%
import networkx as nx
import scipy.stats as sp
import scipy.special as spp
import numpy as np
import matplotlib.pyplot as plt
import powerlaw
import mpmath
from NEMtropy import UndirectedGraph, DirectedGraph
from NEMtropy.network_functions import build_adjacency_from_edgelist
# !pip install python-pptx
# Out:
# Requirement already satisfied: python-pptx in /Users/stefanoskonstantinou/opt/anaconda3/lib/python3.8/site-packages (0.6.21)
# Requirement already satisfied: Pillow>=3.3.2 in /Users/stefanoskonstantinou/opt/anaconda3/lib/python3.8/site-packages (from python-pptx) (8.2.0)
# Requirement already satisfied: lxml>=3.1.0 in /Users/stefanoskonstantinou/opt/anaconda3/lib/python3.8/site-packages (from python-pptx) (4.6.3)
# Requirement already satisfied: XlsxWriter>=0.5.7 in /Users/stefanoskonstantinou/opt/anaconda3/lib/python3.8/site-packages (from python-pptx) (1.3.8)

# %%
def get_colours(graph) -> list:
    from pptx.dml.color import RGBColor
    out = list(dict(graph.nodes.data('color')).values())
    out = list(map(lambda x: x[4:-1], out))
    out = list(map(lambda x: x.split(','), out))
    out = list(map(lambda x: list(map(float, x)),out))
    out = list(map(lambda x: np.array(x)/255, out))
    return out

# %%
def get_sizes(graph) -> list:
    return list(np.array(list(dict(graph.nodes.data('size')).values()))*6)

# %%
def get_positions(graph) -> dict:
    positions = {}
    for p in dict(graph.nodes.data()):
        positions[p] = tuple([float(y) for y in graph.nodes.data()[p]['position'][1:-1].split(',')])
    return positions

# %%
def get_subgraph(graph, classes: list):
    classes = set(classes)
    graph_nodes = dict(graph.nodes.data('disclass'))
    nodes_wanted = [k for k,v in graph_nodes.items() if graph_nodes[k] in classes]
        
    return graph.subgraph(nodes_wanted)

# %%
pp = nx.read_gml("diseases.gml")

# %% [markdown]
# All Classes:

# %%
classes = list(dict(pp.nodes.data('disclass')).values())
print('Classes:')
print()
for c in set(classes):
    print(f'   - {c}')
# Out:
# Classes:
#
#    - Gastrointestinal
#    - Muscular
#    - Endocrine
#    - Immunological
#    - Psychiatric
#    - Developmental
#    - Neurological
#    - Multiple
#    - Metabolic
#    - Nutritional
#    - Skeletal
#    - Unclassified
#    - Cardiovascular
#    - Dermatological
#    - Connective tissue disorder
#    - Cancer
#    - Ear,Nose,Throat
#    - Bone
#    - Respiratory
#    - Ophthamological
#    - Hematological
#    - Renal

# %% [markdown]
# Number of Nodes per Class:

# %%
from collections import Counter
npn = Counter(classes)
s_npn = sorted(npn, key=lambda x: x[1], reverse=True)
s_npn
# Out:
# ['Muscular',
#  'Nutritional',
#  'Multiple',
#  'Psychiatric',
#  'Ophthamological',
#  'Connective tissue disorder',
#  'Bone',
#  'Unclassified',
#  'Endocrine',
#  'Immunological',
#  'Skeletal',
#  'Neurological',
#  'Metabolic',
#  'Hematological',
#  'Respiratory',
#  'Renal',
#  'Dermatological',
#  'Developmental',
#  'Cardiovascular',
#  'Cancer',
#  'Ear,Nose,Throat',
#  'Gastrointestinal']

# %%
plt.figure(figsize=(25,25)) 
nx.draw_networkx(pp, node_color=get_colours(pp), pos=get_positions(pp), node_size=get_sizes(pp), with_labels=False, width=0.1)

# %%
pp.nodes()['0']
# Out:
# {'name': '30',
#  'color': 'rgb(238, 68, 68)',
#  'disclass': 'Neurological',
#  'position': '(-116.486664, -95.29654)',
#  'type': 'disease',
#  'size': 17.46866}

# %%
new = get_subgraph(pp, ['Cancer','Ophthamological'])

# %%
plt.figure(figsize=(25,25)) 
nx.draw_networkx(new, node_color=get_colours(new), pos=get_positions(new), node_size=get_sizes(new), with_labels=False, width=0.1)
